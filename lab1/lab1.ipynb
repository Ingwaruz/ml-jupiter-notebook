# %%
import pandas as pd
import numpy as np
file = pd.read_csv( "bar_pass_prediction.csv" )
file.head()
# Out:
#    decile1b  decile3  ID  decile1  sex  race  cluster  lsat  ugpa  zfygpa  \
# 0      10.0     10.0   2     10.0  1.0   7.0      1.0  44.0   3.5    1.33
# 1       5.0      4.0   3      5.0  1.0   7.0      2.0  29.0   3.5   -0.11
# 2       3.0      2.0  36      3.0  2.0   7.0      3.0  36.0   3.5   -0.64
# 3       7.0      4.0  52      7.0  2.0   7.0      3.0  39.0   3.5    0.34
# 4       9.0      8.0  55      9.0  2.0   7.0      4.0  48.0   3.5    1.02
#
#    ...  hisp pass_bar                bar bar_passed  tier   index6040  \
# 0  ...     0        1  a Passed 1st time       True   4.0  886.842082
# 1  ...     0        1  a Passed 1st time       True   2.0  649.999987
# 2  ...     0        1  a Passed 1st time       True   3.0  760.526298
# 3  ...     0        1  a Passed 1st time       True   3.0  807.894717
# 4  ...     0        1  a Passed 1st time       True   5.0  949.999974
#
#      indxgrp   indxgrp2  dnn_bar_pass_prediction  gpa
# ...

# %%
# Вывести техническую информацию о датасете
type(file)
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22407 entries, 0 to 22406
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   decile1b                 20803 non-null  float64
#  1   decile3                  20803 non-null  float64
#  2   ID                       22407 non-null  int64
#  3   decile1                  21315 non-null  float64
#  4   sex                      22402 non-null  float64
#  5   race                     22391 non-null  float64
#  6   cluster                  22311 non-null  float64
#  7   lsat                     22407 non-null  float64
#  8   ugpa                     22407 non-null  float64
#  9   zfygpa                   21423 non-null  float64
#  10  DOB_yr                   22357 non-null  float64
#  11  grad                     22404 non-null  object
#  12  zgpa                     21118 non-null  float64
# ...

# %%
# номинальные данные
file.lsat
# Out:
# 0        44.0
# 1        29.0
# 2        36.0
# 3        39.0
# 4        48.0
#          ...
# 22402    26.5
# 22403    19.7
# 22404    36.0
# 22405    44.0
# 22406    29.5
# Name: lsat, Length: 22407, dtype: float64

# %%
# категориальные данные
file.indxgrp.unique()
# Out:
# array(['g 700+', 'f 640-700', 'e 580-640', 'd 520-580', 'c 460-520',
#        'b 400-460', 'a under 400'], dtype=object)

# %%
# непрерывные данные
file.cluster.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  6.,  5., nan])

# %%
# статистические характеристики набора
file.describe(include = "all")
# Out:
#             decile1b       decile3            ID       decile1           sex  \
# count   20803.000000  20803.000000  22407.000000  21315.000000  22402.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        5.528481      5.525934  13768.253537      5.708234      1.561378
# std         2.854800      2.851286   7929.063192      2.783098      0.496229
# min         1.000000      1.000000      2.000000      1.000000      1.000000
# 25%         3.000000      3.000000   6926.500000      3.000000      1.000000
# 50%         6.000000      6.000000  13772.000000      6.000000      2.000000
# 75%         8.000000      8.000000  20628.500000      8.000000      2.000000
# max        10.000000     10.000000  27477.000000     10.000000      2.000000
#
# ...

# %%
# Имеются ли пустые значения полей
# Указывает строки с количеством пустых значений
file.isnull().value_counts()
# Out:
# decile1b  decile3  ID     decile1  sex    race   cluster  lsat   ugpa   zfygpa  DOB_yr  grad   zgpa   bar1   bar1_yr  bar2   bar2_yr  fulltime  fam_inc  age    gender  parttime  male   race1  race2  Dropout  other  asian  black  hisp   pass_bar  bar    bar_passed  tier   index6040  indxgrp  indxgrp2  dnn_bar_pass_prediction  gpa
# False     False    False  False    False  False  False    False  False  False   False   False  False  False  False    False  False    False     False    False  False   False     False  False  False  False    False  False  False  False  False     False  False       False  False      False    False     False                    False    20427
# ...

# %%
# Статистические характеристики числовых полей (мин, макс, среднее,медиана).
groups = file.groupby(["lsat"])
max(groups.size())
# Out:
# 1620

# %%
groups = file.groupby(["lsat"])
min(groups.size())
# Out:
# 1

# %%
file.groupby(["sex"])[["lsat"]].mean()
# Out:
#           lsat
# sex
# 1.0  36.290657
# 2.0  37.141659

# %%
file.groupby(["sex"])[["lsat","race"]].median()
# Out:
#      lsat  race
# sex
# 1.0  37.0   7.0
# 2.0  37.0   7.0

# %%
# Выполнить срезы набора данных: по именам полей, по индексам

file.loc[3:10, "lsat" ]
# Out:
# 3     39.0
# 4     48.0
# 5     40.0
# 6     34.0
# 7     40.0
# 8     40.0
# 9     28.0
# 10    33.0
# Name: lsat, dtype: float64

# %%
file.iloc[0:5, 3:5]
# Out:
#    decile1  sex
# 0     10.0  1.0
# 1      5.0  1.0
# 2      3.0  2.0
# 3      7.0  2.0
# 4      9.0  2.0

# %%
# Выполнить выбороки с фильтрацией по значниям полей (равенство, неравенство, частичный фильтр строк с помощью лямбда-функции), с использованием |, &
file.iloc[lambda x: x.index % 2 == 0, [False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False,False, True, True, True, False, False, True, False, False]]
# Out:
#        decile3     ID  decile1  lsat  ugpa  zfygpa bar1  bar1_yr bar2   age  \
# 0         10.0      2     10.0  44.0   3.5    1.33    P      7.0    P -62.0
# 2          2.0     36      3.0  36.0   3.5   -0.64    P      7.0    P -58.0
# 4          8.0     55      9.0  48.0   3.5    1.02    P      7.0    P -61.0
# 6          7.0     74      9.0  34.0   3.5    0.96    P      7.0    P -62.0
# 8          2.0    109      4.0  40.0   3.5   -0.44    P      7.0    P -61.0
# ...        ...    ...      ...   ...   ...     ...  ...      ...  ...   ...
# 22398      4.0   5363      6.0  41.0   1.8    0.21    P      7.0    P -43.0
# 22400      6.0   7260      9.0  31.0   1.8    0.95    F      2.0    F -53.0
# 22402      1.0  10695      3.0  26.5   1.8   -0.58    F      2.0    F -62.0
# 22404      8.0  24704      7.0  36.0   1.8    0.41    P      7.0    P -59.0
# 22406      8.0  10684      9.0  29.5   1.6    1.10    P      2.0    P -57.0
#
# ...

# %%
file[ (file.sex == 1.0) & (file.race == 7.0) ]
# Out:
#        decile1b  decile3     ID  decile1  sex  race  cluster  lsat  ugpa  \
# 0          10.0     10.0      2     10.0  1.0   7.0      1.0  44.0   3.5
# 1           5.0      4.0      3      5.0  1.0   7.0      2.0  29.0   3.5
# 5           3.0      5.0     72      3.0  1.0   7.0      3.0  40.0   3.5
# 6           9.0      7.0     74      9.0  1.0   7.0      3.0  34.0   3.5
# 10          2.0      2.0    144      3.0  1.0   7.0      2.0  33.0   3.5
# ...         ...      ...    ...      ...  ...   ...      ...   ...   ...
# 22381       8.0      3.0  19013      8.0  1.0   7.0      3.0  43.0   1.9
# 22382       NaN      NaN  19746      NaN  1.0   7.0      6.0  31.5   1.9
# 22388       4.0      5.0  24730      5.0  1.0   7.0      3.0  42.0   1.9
# 22393       2.0      1.0   1987      2.0  1.0   7.0      3.0  39.5   1.7
# 22396       8.0     10.0   7366      8.0  1.0   7.0      3.0  42.0   1.7
#
#        zfygpa  ...  hisp pass_bar                bar bar_passed  tier  \
# ...

# %%
file[ (file.sex == 1.0) & (file.race == 7.0) | (file.race == 8.0)]
# Out:
#        decile1b  decile3     ID  decile1  sex  race  cluster  lsat  ugpa  \
# 0          10.0     10.0      2     10.0  1.0   7.0      1.0  44.0   3.5
# 1           5.0      4.0      3      5.0  1.0   7.0      2.0  29.0   3.5
# 5           3.0      5.0     72      3.0  1.0   7.0      3.0  40.0   3.5
# 6           9.0      7.0     74      9.0  1.0   7.0      3.0  34.0   3.5
# 10          2.0      2.0    144      3.0  1.0   7.0      2.0  33.0   3.5
# ...         ...      ...    ...      ...  ...   ...      ...   ...   ...
# 22381       8.0      3.0  19013      8.0  1.0   7.0      3.0  43.0   1.9
# 22382       NaN      NaN  19746      NaN  1.0   7.0      6.0  31.5   1.9
# 22388       4.0      5.0  24730      5.0  1.0   7.0      3.0  42.0   1.9
# 22393       2.0      1.0   1987      2.0  1.0   7.0      3.0  39.5   1.7
# 22396       8.0     10.0   7366      8.0  1.0   7.0      3.0  42.0   1.7
#
#        zfygpa  ...  hisp pass_bar                bar bar_passed  tier  \
# ...

# %%
# Выполнить сортировку отфильтрованного набора данных
# ascending = [True, False, False] выполняет сортировку в зависимости, что там стоит по убыванию или по возрастанию
file[ file.sex == 1 ].sort_values( by = ["lsat", "race", "ugpa"], ascending = [True, False, False] )
# Out:
#        decile1b  decile3     ID  decile1  sex  race  cluster  lsat  ugpa  \
# 11513       2.0      2.0  22787      2.0  1.0   6.0      3.0  12.0   2.9
# 15359       1.0      1.0   7118      1.0  1.0   3.0      4.0  13.5   2.7
# 10465       5.0      5.0   2331      6.0  1.0   3.0      6.0  14.0   2.9
# 6350        1.0      1.0   2559      2.0  1.0   3.0      2.0  14.5   3.2
# 11454       1.0      1.0  21649      1.0  1.0   6.0      4.0  15.0   2.9
# ...         ...      ...    ...      ...  ...   ...      ...   ...   ...
# 14850       6.0      5.0  22369      6.0  1.0   2.0      4.0  48.0   3.7
# 9780        6.0      7.0  19087      6.0  1.0   2.0      4.0  48.0   3.6
# 1403        NaN      NaN  19809      NaN  1.0   2.0      5.0  48.0   3.5
# 1854       10.0     10.0  26384     10.0  1.0   2.0      1.0  48.0   3.5
# 9542        NaN      NaN  15586      NaN  1.0   NaN      5.0  48.0   3.6
#
#        zfygpa  ...  hisp pass_bar                bar bar_passed  tier  \
# ...

# %%
# Выполнить группировку данных по некоторым признакам (на основе предварительного анализа содержимого набора данных)
file.groupby(["sex"])[["race","ugpa"]].agg( [np.mean, np.min, np.max] )
# Out:
#          race                ugpa
#          mean amin amax      mean amin amax
# sex
# 1.0  6.334861  1.0  8.0  3.277417  1.7  3.9
# 2.0  6.555034  1.0  8.0  3.167009  1.5  3.9

# %%
# Выполнить объединение таблиц с различнымы типами присоединения (если нет возможности выполнить эту операцию с загруженным набором, то допускается создать собственные наборы)
lec = pd.read_csv("student-mat.csv")
lec.head()

merge = pd.merge(file, lec,
                       how='left', left_index=True, right_index=True)
merge.head()
# Out:
#    decile1b  decile3  ID  decile1  sex_x  race  cluster  lsat  ugpa  zfygpa  \
# 0      10.0     10.0   2     10.0    1.0   7.0      1.0  44.0   3.5    1.33
# 1       5.0      4.0   3      5.0    1.0   7.0      2.0  29.0   3.5   -0.11
# 2       3.0      2.0  36      3.0    2.0   7.0      3.0  36.0   3.5   -0.64
# 3       7.0      4.0  52      7.0    2.0   7.0      3.0  39.0   3.5    0.34
# 4       9.0      8.0  55      9.0    2.0   7.0      4.0  48.0   3.5    1.02
#
#    ...  famrel freetime  goout Dalc  Walc health  absences    G1    G2    G3
# 0  ...     4.0      3.0    4.0  1.0   1.0    3.0       6.0   5.0   6.0   6.0
# 1  ...     5.0      3.0    3.0  1.0   1.0    3.0       4.0   5.0   5.0   6.0
# 2  ...     4.0      3.0    2.0  2.0   3.0    3.0      10.0   7.0   8.0  10.0
# 3  ...     3.0      2.0    2.0  1.0   1.0    5.0       2.0  15.0  14.0  15.0
# 4  ...     4.0      3.0    2.0  1.0   2.0    5.0       4.0   6.0  10.0  10.0
#
# [5 rows x 72 columns]

# %%
merge = pd.merge(file, lec,
                       how='left', left_on='ID', right_on='age')
merge.head()
# Out:
#    decile1b  decile3  ID  decile1  sex_x  race  cluster  lsat  ugpa  zfygpa  \
# 0      10.0     10.0   2     10.0    1.0   7.0      1.0  44.0   3.5    1.33
# 1       5.0      4.0   3      5.0    1.0   7.0      2.0  29.0   3.5   -0.11
# 2       3.0      2.0  36      3.0    2.0   7.0      3.0  36.0   3.5   -0.64
# 3       7.0      4.0  52      7.0    2.0   7.0      3.0  39.0   3.5    0.34
# 4       9.0      8.0  55      9.0    2.0   7.0      4.0  48.0   3.5    1.02
#
#    ...  famrel freetime  goout Dalc  Walc health  absences  G1  G2  G3
# 0  ...     NaN      NaN    NaN  NaN   NaN    NaN       NaN NaN NaN NaN
# 1  ...     NaN      NaN    NaN  NaN   NaN    NaN       NaN NaN NaN NaN
# 2  ...     NaN      NaN    NaN  NaN   NaN    NaN       NaN NaN NaN NaN
# 3  ...     NaN      NaN    NaN  NaN   NaN    NaN       NaN NaN NaN NaN
# 4  ...     NaN      NaN    NaN  NaN   NaN    NaN       NaN NaN NaN NaN
#
# [5 rows x 72 columns]
